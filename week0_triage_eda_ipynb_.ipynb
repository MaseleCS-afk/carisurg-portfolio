# %% [markdown]
# <a href="https://colab.research.google.com/github/MaseleCS-afk/carisurg-portfolio/blob/main/week0_triage_eda_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.makedirs('/content/drive/MyDrive/carisurge-portfolio',exist_ok=True)
print("Folder ready!")
# Out:
# Folder ready!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_raw = pd.read_csv('/content/drive/MyDrive/EmergencyTriageDataset_Reduced_Dirty.csv')
print(f"Dataset: {df_raw.shape[0]} rows x {df_raw.shape[1]} columns")
print(list(df_raw.columns))
# Out:
# Dataset: 2205 rows x 11 columns
# ['ID', 'Age', 'Gender', 'GCS', 'SBP', 'DBP', 'MAP', 'pulse', 'Temp', 'RR', 'Fio2']

# %%
gender_map={'Male':1, 'MALE':1,'1':1,
            'Female':0,'FEMALE':0,'0':0}
df_raw['Gender_Clean'] = df_raw['Gender'].map(gender_map)
print(df_raw['Gender_Clean'].value_counts())
print(f"NaNs:{df_raw['Gender_Clean'].isnull().sum()}")
# Out:
# Gender_Clean
# 1    1176
# 0    1029
# Name: count, dtype: int64
# NaNs:0

# %%
df_raw=df_raw.drop(columns=['Gender'])
df_raw=df_raw.rename(columns={'Gender_Clean':'Gender'})
df_raw.head()
# Out:
#    ID  Age   GCS  SBP    DBP     MAP  pulse  Temp    RR   Fio2  Gender
# 0   1   34  15.0   93   67.0   75.67  128.0  36.8  14.0   21.0       0
# 1   2   20  15.0  130   90.0  103.33   80.0  37.0  16.0   21.0       1
# 2   3   77  14.0  163  105.0  124.33   92.0  36.8  18.0   21.0       0
# 3   4   23   8.0  100   60.0   73.33  100.0  37.0  12.0  100.0       0
# 4   5   86  15.0  150   90.0  110.00   85.0  37.0  19.0   21.0       0

# %% [markdown]
# ## **</>Final Markdown**
#
# In this section, I loaded the Emergency Triage dataset into Google Colab and explored its structure by checking the number of rows, columns, and column names. I then cleaned the `Gender` column by mapping different text variations such as `Male`, `MALE`, `Female`, and numeric values into a consistent binary format. After verifying the cleaned values and checking for missing data, I removed the original dirty column and renamed the cleaned column to `Gender` for consistency.*italicized text*
